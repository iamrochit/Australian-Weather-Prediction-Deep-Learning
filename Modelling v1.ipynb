# %% [markdown]
# <h1 align='center'>Rain Prediction using ANN</h1>
# <h1 align='center'>Assignment 2 - Set 7</h1><hr>
# <h2>Group - 270<br><br>Rochit Jain - 2020sc04439<br><br>Suraj Jha - 2020sc04853</h2> <hr>

# %% [markdown]
# ## Importing Libraries

# %%
# for data manipulation
import numpy as np 
import pandas as pd 

from sklearn.model_selection import train_test_split # for splitting the data into train and test samples
from sklearn.metrics import classification_report # for model evaluation metrics
from sklearn.preprocessing import LabelEncoder # for encoding categorical features from strings to number arrays
from sklearn.manifold import TSNE # to visualize high-dimensional data
from sklearn.metrics import confusion_matrix # for model confusion matrix
from sklearn.impute import SimpleImputer # for Missing value imputation
from sklearn.decomposition import PCA # for dimensions reduction

# for data visualization
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

from IPython.display import display # for object display

# for ANN modelling
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Defining Utility function

# %%
# Function to get categorical column volumetric analysis
def get_volumetric(dataset, col):
    col_volumetric = dataset[col].value_counts(dropna=False).reset_index()
    col_volumetric.columns = [col, 'volume']
    col_volumetric['%volume'] = ((col_volumetric['volume']*100)/col_volumetric['volume'].sum()).round(2)
    return col_volumetric

# Function to check and get the missingValue volumetric analysis
def check_missingValue(dataset):
    null_volumetric = dataset.isnull().sum().reset_index()
    null_volumetric.columns = ['Column', 'Missing value']
    null_volumetric['%Missing value'] = ((null_volumetric['Missing value']*100)/dataset.shape[0]).round(2)
    return null_volumetric

# Function to plot the confusion matrix
def plot_cm(y_true, y_pred, figsize=(8,6)):
    # get the confusion matrix
    cm = confusion_matrix(y_true, y_pred, labels=np.unique(y_true))
    
    # plotting the heatmap
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=np.unique(y_true), columns=np.unique(y_true))
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, cmap= "Blues", annot=annot, fmt='', ax=ax)

# %% [markdown]
# ## Importing Dataset

# %% [markdown]
# ### Rain Prediction
#
# - Context:
#     - Predict next-day rain by training classification models on the target variable RainTomorrow.
#
#
# - Content:
#     - This dataset contains about 10 years of daily weather observations from many locations across Australia.
#
#     - RainTomorrow is the target variable to predict. It means -- did it rain the next day, Yes or No? This column is Yes if the rain for that day was 1mm or more.

# %%
dataset = pd.read_csv("weatherAUS.csv", index_col=False)

print("Dataset Shape:", dataset.shape)
# Out:
# Dataset Shape: (145460, 23)

# %% [markdown]
# ## Data Visualization and Exploration

# %% [markdown]
# Printing the first 5 & last 5 rows for sanity check to identify all the features present in the dataset and if the target matches with them.

# %%
# First 5 rows
print("First 5 rows of the dataset")
display(dataset.head(5))

# Last rows
print("Last 5 rows of the dataset")
display(dataset.tail(5))
# Out:
# First 5 rows of the dataset
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]
# Last 5 rows of the dataset
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Univariate & Multivariate Descriptive Analysis

# %% [markdown]
# #### Target Column Distribution - Income

# %%
# Getting the income class distribution 
target_volumetric =  get_volumetric(dataset, 'RainTomorrow')
display(target_volumetric)

# Plotting a pie chart
colors = sns.color_palette('pastel')[0:5]
plt.figure(figsize=(7,7))
plt.title("RainTomorrow distribution")
plt.pie(target_volumetric['%volume'], 
        labels = target_volumetric['RainTomorrow'], 
        colors = colors, autopct='%.0f%%')
plt.show();
# Out:
#   RainTomorrow  volume  %volume
# 0           No  110316    75.84
# 1          Yes   31877    21.91
# 2          NaN    3267     2.25

# %%
# Printing a concise summary of a DataFrame.
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %%
# Creating column's subsets as per the datatype
dataset_dtypes = dataset.dtypes.reset_index()
dataset_dtypes.columns = ['variable', 'dtype']
# Getting the categorical columns
cat_cols = dataset_dtypes[dataset_dtypes['dtype']=='object']['variable'].tolist()
# Getting the continuos columns
cont_cols = dataset_dtypes[dataset_dtypes['dtype']!='object']['variable'].tolist()

print("Categorical Columns:", cat_cols)
print()
print("Continuos Columns:", cont_cols)
# Out:
# Categorical Columns: ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']
#
# Continuos Columns: ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %% [markdown]
# #### Categorical Columns

# %%
# Descriptive statistics include those that summarize the count, unique and top category freq of a dataset’s distribution.
dataset[cat_cols].describe().T
# Out:
#                count unique         top    freq
# Date          145460   3436  2013-11-12      49
# Location      145460     49    Canberra    3436
# WindGustDir   135134     16           W    9915
# WindDir9am    134894     16           N   11758
# WindDir3pm    141232     16          SE   10838
# RainToday     142199      2          No  110319
# RainTomorrow  142193      2          No  110316

# %%
# Getting the category volume distribution and cardinality
for col in cat_cols:
    cat_volumteric_t = get_volumetric(dataset, col)
    print(col)
    print(f"Unique Category preset: {cat_volumteric_t.shape[0]}")
    display(cat_volumteric_t)
    print()
# Out:
# Date
# Unique Category preset: 3436
#             Date  volume  %volume
# 0     2013-11-12      49     0.03
# 1     2014-09-01      49     0.03
# 2     2014-08-23      49     0.03
# 3     2014-08-24      49     0.03
# 4     2014-08-25      49     0.03
# ...          ...     ...      ...
# 3431  2007-11-29       1     0.00
# 3432  2007-11-28       1     0.00
# 3433  2007-11-27       1     0.00
# 3434  2007-11-26       1     0.00
# 3435  2008-01-31       1     0.00
#
# [3436 rows x 3 columns]
# Location
# Unique Category preset: 49
#             Location  volume  %volume
# 0           Canberra    3436     2.36
# 1             Sydney    3344     2.30
# 2             Darwin    3193     2.20
# 3          Melbourne    3193     2.20
# 4           Brisbane    3193     2.20
# 5           Adelaide    3193     2.20
# 6              Perth    3193     2.20
# 7             Hobart    3193     2.20
# 8             Albany    3040     2.09
# 9       MountGambier    3040     2.09
# 10          Ballarat    3040     2.09
# 11        Townsville    3040     2.09
# 12         GoldCoast    3040     2.09
# 13            Cairns    3040     2.09
# 14        Launceston    3040     2.09
# 15      AliceSprings    3040     2.09
# 16           Bendigo    3040     2.09
# 17            Albury    3040     2.09
# 18       MountGinini    3040     2.09
# 19        Wollongong    3040     2.09
# 20         Newcastle    3039     2.09
# 21       Tuggeranong    3039     2.09
# 22           Penrith    3039     2.09
# 23           Woomera    3009     2.07
# 24         Nuriootpa    3009     2.07
# 25             Cobar    3009     2.07
# 26      CoffsHarbour    3009     2.07
# 27             Moree    3009     2.07
# 28              Sale    3009     2.07
# 29      PerthAirport    3009     2.07
# 30        PearceRAAF    3009     2.07
# 31       Witchcliffe    3009     2.07
# 32     BadgerysCreek    3009     2.07
# 33           Mildura    3009     2.07
# 34     NorfolkIsland    3009     2.07
# 35  MelbourneAirport    3009     2.07
# 36          Richmond    3009     2.07
# 37     SydneyAirport    3009     2.07
# 38        WaggaWagga    3009     2.07
# 39       Williamtown    3009     2.07
# 40          Dartmoor    3009     2.07
# 41          Watsonia    3009     2.07
# 42          Portland    3009     2.07
# 43           Walpole    3006     2.07
# 44         NorahHead    3004     2.07
# 45        SalmonGums    3001     2.06
# 46         Katherine    1578     1.08
# 47              Nhil    1578     1.08
# 48             Uluru    1578     1.08
# WindGustDir
# Unique Category preset: 17
#    WindGustDir  volume  %volume
# 0          NaN   10326     7.10
# 1            W    9915     6.82
# 2           SE    9418     6.47
# 3            N    9313     6.40
# 4          SSE    9216     6.34
# 5            E    9181     6.31
# 6            S    9168     6.30
# 7          WSW    9069     6.23
# 8           SW    8967     6.16
# 9          SSW    8736     6.01
# 10         WNW    8252     5.67
# 11          NW    8122     5.58
# 12         ENE    8104     5.57
# 13         ESE    7372     5.07
# 14          NE    7133     4.90
# 15         NNW    6620     4.55
# 16         NNE    6548     4.50
# WindDir9am
# Unique Category preset: 17
#    WindDir9am  volume  %volume
# 0           N   11758     8.08
# 1         NaN   10566     7.26
# 2          SE    9287     6.38
# 3           E    9176     6.31
# 4         SSE    9112     6.26
# 5          NW    8749     6.01
# 6           S    8659     5.95
# 7           W    8459     5.82
# 8          SW    8423     5.79
# 9         NNE    8129     5.59
# 10        NNW    7980     5.49
# 11        ENE    7836     5.39
# 12         NE    7671     5.27
# 13        ESE    7630     5.25
# 14        SSW    7587     5.22
# 15        WNW    7414     5.10
# 16        WSW    7024     4.83
# WindDir3pm
# Unique Category preset: 17
#    WindDir3pm  volume  %volume
# 0          SE   10838     7.45
# 1           W   10110     6.95
# 2           S    9926     6.82
# 3         WSW    9518     6.54
# 4         SSE    9399     6.46
# 5          SW    9354     6.43
# 6           N    8890     6.11
# 7         WNW    8874     6.10
# 8          NW    8610     5.92
# 9         ESE    8505     5.85
# 10          E    8472     5.82
# 11         NE    8263     5.68
# 12        SSW    8156     5.61
# 13        NNW    7870     5.41
# 14        ENE    7857     5.40
# 15        NNE    6590     4.53
# 16        NaN    4228     2.91
# RainToday
# Unique Category preset: 3
#   RainToday  volume  %volume
# 0        No  110319    75.84
# 1       Yes   31880    21.92
# 2       NaN    3261     2.24
# RainTomorrow
# Unique Category preset: 3
#   RainTomorrow  volume  %volume
# 0           No  110316    75.84
# 1          Yes   31877    21.91
# 2          NaN    3267     2.25

# %% [markdown]
# ### Bi-Variate EDA on Categorical Attributes (Fetaures) w.r.t Exited

# %%
# Cross table plot

ns = int(dataset.shape[0]*.90)
dataset_sample = dataset.sample(n = ns).fillna('Null')

for col in cat_cols:
    if col not in ["RainTomorrow", "Date"]:
        fig = plt.figure(figsize=(14, 6));
        ax = fig.gca();
        ax.tick_params(axis='x', rotation=90)
        sns.countplot(x=col, hue="RainTomorrow", data=dataset_sample, palette="Set2", ax = ax)

# %% [markdown]
# #### Continuos Columns

# %%
# Descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset’s distribution.
dataset[cont_cols].describe(percentiles=[.05,.25,.50,.75,.95]).round(2).T
# Out:
#                   count     mean    std    min      5%     25%     50%  \
# MinTemp        143975.0    12.19   6.40   -8.5     1.8     7.6    12.0
# MaxTemp        144199.0    23.22   7.12   -4.8    12.8    17.9    22.6
# Rainfall       142199.0     2.36   8.48    0.0     0.0     0.0     0.0
# Evaporation     82670.0     5.47   4.19    0.0     1.0     2.6     4.8
# Sunshine        75625.0     7.61   3.79    0.0     0.3     4.8     8.4
# WindGustSpeed  135197.0    40.04  13.61    6.0    20.0    31.0    39.0
# WindSpeed9am   143693.0    14.04   8.92    0.0     0.0     7.0    13.0
# WindSpeed3pm   142398.0    18.66   8.81    0.0     6.0    13.0    19.0
# Humidity9am    142806.0    68.88  19.03    0.0    34.0    57.0    70.0
# Humidity3pm    140953.0    51.54  20.80    0.0    17.0    37.0    52.0
# Pressure9am    130395.0  1017.65   7.11  980.5  1006.2  1012.9  1017.6
# Pressure3pm    130432.0  1015.26   7.04  977.1  1004.0  1010.4  1015.2
# Cloud9am        89572.0     4.45   2.89    0.0     0.0     1.0     5.0
# Cloud3pm        86102.0     4.51   2.72    0.0     0.0     2.0     5.0
# Temp9am        143693.0    16.99   6.49   -7.2     6.9    12.3    16.7
# Temp3pm        141851.0    21.68   6.94   -5.4    11.6    16.6    21.1
#
#                   75%     95%     max
# MinTemp          16.9    23.0    33.9
# MaxTemp          28.2    35.5    48.1
# Rainfall          0.8    13.0   371.0
# Evaporation       7.4    12.0   145.0
# Sunshine         10.6    12.8    14.5
# WindGustSpeed    48.0    65.0   135.0
# WindSpeed9am     19.0    30.0   130.0
# WindSpeed3pm     24.0    35.0    87.0
# Humidity9am      83.0    98.0   100.0
# Humidity3pm      66.0    88.0   100.0
# Pressure9am    1022.4  1029.5  1041.0
# Pressure3pm    1020.0  1026.9  1039.6
# Cloud9am          7.0     8.0     9.0
# Cloud3pm          7.0     8.0     9.0
# Temp9am          21.6    28.2    40.2
# Temp3pm          26.4    33.7    46.7

# %% [markdown]
# ### Bi-Variate EDA on Continuos Attributes (Features) w.r.t to Exited

# %%
for col in cont_cols:
    fig = plt.figure(figsize=(12, 5))
    ax = fig.gca()
    plt.title(f"Box plot for {col} w.r.t RainTomorrow")
    sns.boxplot( x = col, y = 'RainTomorrow', data=dataset, ax = ax);

# %% [markdown]
# ### Correlation Analysis

# %%
fig = plt.figure(figsize=(16, 10));
sns.heatmap(dataset[cont_cols].corr(), cmap="YlGnBu",  annot=True, linewidths ='.02');

# %% [markdown]
# ## Data Pre-processing and cleaning

# %%
# Creating a copy of dataset
data_raw = dataset.copy()

# %% [markdown]
# ### Checking for Missing Values

# %%
null_volumetric = check_missingValue(dataset)
null_volumetric.sort_values(by = '%Missing value', ascending=False)
# Out:
#            Column  Missing value  %Missing value
# 6        Sunshine          69835           48.01
# 5     Evaporation          62790           43.17
# 18       Cloud3pm          59358           40.81
# 17       Cloud9am          55888           38.42
# 15    Pressure9am          15065           10.36
# 16    Pressure3pm          15028           10.33
# 9      WindDir9am          10566            7.26
# 7     WindGustDir          10326            7.10
# 8   WindGustSpeed          10263            7.06
# 14    Humidity3pm           4507            3.10
# 10     WindDir3pm           4228            2.91
# 20        Temp3pm           3609            2.48
# 22   RainTomorrow           3267            2.25
# 4        Rainfall           3261            2.24
# 21      RainToday           3261            2.24
# 12   WindSpeed3pm           3062            2.11
# 13    Humidity9am           2654            1.82
# 19        Temp9am           1767            1.21
# 11   WindSpeed9am           1767            1.21
# 2         MinTemp           1485            1.02
# 3         MaxTemp           1261            0.87
# 1        Location              0            0.00
# 0            Date              0            0.00

# %% [markdown]
# ### Missing Value Treatment

# %% [markdown]
# - <b>Dropping rows where target "RainTomorrow" is null</b>

# %%
data_tw = data_raw.dropna(subset = ["RainTomorrow"])
print("Shape of the data after droping missing value present in RainTomorrow")
print(data_tw.shape)
# Out:
# Shape of the data after droping missing value present in RainTomorrow
# (142193, 23)

# %% [markdown]
# - <b>Dropping columns where "%Missing Value" is more than ~40%* because imputing may add unwanted bias in the data</b>

# %%
cols_to_drop = ['Evaporation', 'Sunshine', 'Cloud9am', 'Cloud3pm']
data_tw = data_raw.drop(columns = cols_to_drop)

print(f"Shape of the data after droping missing value present in {cols_to_drop}")
print(data_tw.shape)
# Out:
# Shape of the data after droping missing value present in ['Evaporation', 'Sunshine', 'Cloud9am', 'Cloud3pm']
# (145460, 19)

# %% [markdown]
# - <b>Imputing the missing values</b>

# %%
imputer = SimpleImputer(strategy="most_frequent")
imputed_array = imputer.fit_transform(data_tw)

data_tw_imputed = pd.DataFrame(imputed_array, columns=data_tw.columns)

print(f"Shape of the data after imputing missing values")
print(data_tw_imputed.shape)
# Out:
# Shape of the data after imputing missing values
# (145460, 19)

# %% [markdown]
# Missing value imputation post check

# %%
null_volumetric = check_missingValue(data_tw_imputed)
null_volumetric.sort_values(by = '%Missing value', ascending=False)
# Out:
#            Column  Missing value  %Missing value
# 0            Date              0             0.0
# 10   WindSpeed3pm              0             0.0
# 17      RainToday              0             0.0
# 16        Temp3pm              0             0.0
# 15        Temp9am              0             0.0
# 14    Pressure3pm              0             0.0
# 13    Pressure9am              0             0.0
# 12    Humidity3pm              0             0.0
# 11    Humidity9am              0             0.0
# 9    WindSpeed9am              0             0.0
# 1        Location              0             0.0
# 8      WindDir3pm              0             0.0
# 7      WindDir9am              0             0.0
# 6   WindGustSpeed              0             0.0
# 5     WindGustDir              0             0.0
# 4        Rainfall              0             0.0
# 3         MaxTemp              0             0.0
# 2         MinTemp              0             0.0
# 18   RainTomorrow              0             0.0

# %% [markdown]
# ### Extracting Year, Month, Week, Day of the week from "Date"

# %%
data_tw_imputed["Date"] = pd.to_datetime(data_tw_imputed["Date"])

data_tw_imputed['Year'] = data_tw_imputed["Date"].dt.year.astype(object)
data_tw_imputed['Month'] = data_tw_imputed["Date"].dt.month.astype(object)
data_tw_imputed['Week'] = data_tw_imputed["Date"].dt.week.astype(object)
data_tw_imputed['dayofweek'] = data_tw_imputed["Date"].dt.dayofweek.astype(object)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   """

# %%
# Getting the feature list 

target = 'RainTomorrow'
cont_cols2 = list(set(cont_cols) - set(cols_to_drop) - set([target]))
cat_cols2 = list(set(cat_cols) - set(cols_to_drop) - set([target, 'Date'])) + ['Year', 'Month', 'Week', 'dayofweek']

for col in cont_cols2:
    data_tw_imputed[col] = data_tw_imputed[col].astype(float)

for col in cat_cols2:
    data_tw_imputed[col] = data_tw_imputed[col].astype(object)
    
print("Features after missing value treatment:\n")
print(f"Target: {target}")
print()
print(f"Continuos Features: {cont_cols2}")
print()
print(f"Categorical Features: {cat_cols2}")
# Out:
# Features after missing value treatment:
#
# Target: RainTomorrow
#
# Continuos Features: ['MinTemp', 'Humidity9am', 'Rainfall', 'Pressure9am', 'Pressure3pm', 'Humidity3pm', 'Temp9am', 'WindGustSpeed', 'MaxTemp', 'Temp3pm', 'WindSpeed9am', 'WindSpeed3pm']
#
# Categorical Features: ['RainToday', 'WindDir9am', 'Location', 'WindGustDir', 'WindDir3pm', 'Year', 'Month', 'Week', 'dayofweek']

# %%
# Creating a copy of imputed dataset for quick rollback
data_tw_level2 = data_tw_imputed.copy()

# %% [markdown]
# ### Label Encoding the Target Variable "RainTomorrow"

# %%
target_en = LabelEncoder()
data_tw_level2[target] = target_en.fit_transform(data_tw_level2[target])

# %%
get_volumetric(data_tw_level2, target)
# Out:
#    RainTomorrow  volume  %volume
# 0             0  113583    78.09
# 1             1   31877    21.91

# %% [markdown]
# ### Standardizing &  Correcting the skewness of Continous Features by applying log transformation

# %%
for col in cont_cols2:
    print(f"Applying log Transformation {col}")
    data_tw_level2[col] = data_tw_level2[col].apply(lambda x: np.log2(x+0.001))
# Out:
# Applying log Transformation MinTemp
# Applying log Transformation Humidity9am
# Applying log Transformation Rainfall
# Applying log Transformation Pressure9am
# Applying log Transformation Pressure3pm
# Applying log Transformation Humidity3pm
# Applying log Transformation Temp9am
# Applying log Transformation WindGustSpeed
# Applying log Transformation MaxTemp
# Applying log Transformation Temp3pm
# Applying log Transformation WindSpeed9am
# Applying log Transformation WindSpeed3pm

# %% [markdown]
# ### Applying One-hot Encoding on Categorical Features

# %%
data_tw_level2 = pd.get_dummies(data_tw_level2, columns=cat_cols2, drop_first=True)

# %%
print("Shape of the dataset after encoding:", data_tw_level2.shape)
# Out:
# Shape of the dataset after encoding: (145460, 187)

# %% [markdown]
# ## Data Preparation

# %%
feature_list = set(data_tw_level2.columns) - set([target, 'Date'])

X = data_tw_level2[feature_list].astype(float)
y = data_tw_level2[target].values

print(f"Dataset Shape:\n\nX -> {X.shape}\ny -> {y.shape}")

# Applying PCA to reduce the dimensions and sparsity
pca = PCA(n_components=32)
X_reduced = pca.fit_transform(X.fillna(0.0))

# Keeping 20% of the data aside for testing
X_train, X_test, y_train, y_test = train_test_split(X_reduced, y, test_size = .20, random_state=2020)

print(f"\nTrain-Test Shape:\n \nX_train -> {X_train.shape} \t y_train -> {y_train.shape} \nX_test ->  {X_test.shape} \t y_test -> {y_test.shape}")
# Out:
# Dataset Shape:
#
# X -> (145460, 185)
# y -> (145460,)
#
# Train-Test Shape:
#
# X_train -> (116368, 32) 	 y_train -> (116368,)
# X_test ->  (29092, 32) 	 y_test -> (29092,)

# %% [markdown]
# ## Model Building

# %%
# Initialising the ANN

leaky_relu = tf.keras.layers.LeakyReLU(alpha=0.3)

model = Sequential()
model.add(Dense(units = 32, activation = leaky_relu, input_dim = 32))
model.add(Dense(units = 32, activation = leaky_relu))
model.add(Dense(units = 16, activation = leaky_relu))
model.add(Dense(units = 8,  activation = leaky_relu))
model.add(Dense(units = 1, activation = 'sigmoid'))

print("ANN Model Summary:")
model.summary()
print()

# Compiling the ANN
adam = Adam(learning_rate=0.00001)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])

# Training the ANN
history = model.fit(X_train,
                    y_train, 
                    batch_size = 128, 
                    epochs = 100, 
                    validation_split=0.2)
# Out:
# ANN Model Summary:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 8)                 136
#
#  dense_4 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 2,785
# Trainable params: 2,785
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/100
# 728/728 [==============================] - 3s 3ms/step - loss: 0.7305 - accuracy: 0.3629 - val_loss: 0.6634 - val_accuracy: 0.6041
# Epoch 2/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.6028 - accuracy: 0.7035 - val_loss: 0.5527 - val_accuracy: 0.7300
# Epoch 3/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.5261 - accuracy: 0.7394 - val_loss: 0.5069 - val_accuracy: 0.7470
# Epoch 4/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4976 - accuracy: 0.7585 - val_loss: 0.4904 - val_accuracy: 0.7663
# Epoch 5/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4850 - accuracy: 0.7712 - val_loss: 0.4807 - val_accuracy: 0.7721
# Epoch 6/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4765 - accuracy: 0.7770 - val_loss: 0.4736 - val_accuracy: 0.7756
# Epoch 7/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4699 - accuracy: 0.7793 - val_loss: 0.4676 - val_accuracy: 0.7779
# Epoch 8/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4640 - accuracy: 0.7808 - val_loss: 0.4621 - val_accuracy: 0.7797
# Epoch 9/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4586 - accuracy: 0.7820 - val_loss: 0.4568 - val_accuracy: 0.7804
# Epoch 10/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4534 - accuracy: 0.7830 - val_loss: 0.4517 - val_accuracy: 0.7817
# Epoch 11/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4484 - accuracy: 0.7842 - val_loss: 0.4469 - val_accuracy: 0.7837
# Epoch 12/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4438 - accuracy: 0.7861 - val_loss: 0.4425 - val_accuracy: 0.7868
# Epoch 13/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4395 - accuracy: 0.7891 - val_loss: 0.4384 - val_accuracy: 0.7904
# Epoch 14/100
# 728/728 [==============================] - 2s 2ms/step - loss: 0.4357 - accuracy: 0.7935 - val_loss: 0.4348 - val_accuracy: 0.7945
# Epoch 15/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4322 - accuracy: 0.7979 - val_loss: 0.4316 - val_accuracy: 0.8003
# Epoch 16/100
# 728/728 [==============================] - 2s 2ms/step - loss: 0.4292 - accuracy: 0.8025 - val_loss: 0.4287 - val_accuracy: 0.8044
# Epoch 17/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4265 - accuracy: 0.8059 - val_loss: 0.4262 - val_accuracy: 0.8076
# Epoch 18/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4240 - accuracy: 0.8086 - val_loss: 0.4239 - val_accuracy: 0.8104
# Epoch 19/100
# 728/728 [==============================] - 2s 2ms/step - loss: 0.4217 - accuracy: 0.8112 - val_loss: 0.4217 - val_accuracy: 0.8125
# Epoch 20/100
# 728/728 [==============================] - 2s 2ms/step - loss: 0.4196 - accuracy: 0.8132 - val_loss: 0.4197 - val_accuracy: 0.8150
# Epoch 21/100
# 728/728 [==============================] - 2s 2ms/step - loss: 0.4176 - accuracy: 0.8145 - val_loss: 0.4178 - val_accuracy: 0.8168
# Epoch 22/100
# 728/728 [==============================] - 2s 2ms/step - loss: 0.4157 - accuracy: 0.8168 - val_loss: 0.4160 - val_accuracy: 0.8182
# Epoch 23/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4140 - accuracy: 0.8180 - val_loss: 0.4143 - val_accuracy: 0.8195
# Epoch 24/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4123 - accuracy: 0.8197 - val_loss: 0.4127 - val_accuracy: 0.8210
# Epoch 25/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4108 - accuracy: 0.8205 - val_loss: 0.4112 - val_accuracy: 0.8216
# Epoch 26/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4093 - accuracy: 0.8221 - val_loss: 0.4098 - val_accuracy: 0.8226
# Epoch 27/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4079 - accuracy: 0.8231 - val_loss: 0.4085 - val_accuracy: 0.8222
# Epoch 28/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4066 - accuracy: 0.8235 - val_loss: 0.4072 - val_accuracy: 0.8231
# Epoch 29/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4054 - accuracy: 0.8243 - val_loss: 0.4060 - val_accuracy: 0.8240
# Epoch 30/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4042 - accuracy: 0.8246 - val_loss: 0.4049 - val_accuracy: 0.8254
# Epoch 31/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4032 - accuracy: 0.8252 - val_loss: 0.4038 - val_accuracy: 0.8253
# Epoch 32/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4022 - accuracy: 0.8261 - val_loss: 0.4028 - val_accuracy: 0.8259
# Epoch 33/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4012 - accuracy: 0.8267 - val_loss: 0.4019 - val_accuracy: 0.8261
# Epoch 34/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.4003 - accuracy: 0.8270 - val_loss: 0.4010 - val_accuracy: 0.8266
# Epoch 35/100
# 728/728 [==============================] - 2s 2ms/step - loss: 0.3994 - accuracy: 0.8275 - val_loss: 0.4001 - val_accuracy: 0.8283
# Epoch 36/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3986 - accuracy: 0.8279 - val_loss: 0.3994 - val_accuracy: 0.8275
# Epoch 37/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3978 - accuracy: 0.8283 - val_loss: 0.3986 - val_accuracy: 0.8277
# Epoch 38/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3970 - accuracy: 0.8290 - val_loss: 0.3978 - val_accuracy: 0.8279
# Epoch 39/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3963 - accuracy: 0.8293 - val_loss: 0.3971 - val_accuracy: 0.8283
# Epoch 40/100
# 728/728 [==============================] - 3s 4ms/step - loss: 0.3956 - accuracy: 0.8297 - val_loss: 0.3965 - val_accuracy: 0.8286
# Epoch 41/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3950 - accuracy: 0.8300 - val_loss: 0.3958 - val_accuracy: 0.8286
# Epoch 42/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3944 - accuracy: 0.8305 - val_loss: 0.3952 - val_accuracy: 0.8290
# Epoch 43/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3937 - accuracy: 0.8310 - val_loss: 0.3946 - val_accuracy: 0.8289
# Epoch 44/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3932 - accuracy: 0.8311 - val_loss: 0.3941 - val_accuracy: 0.8295
# Epoch 45/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3926 - accuracy: 0.8314 - val_loss: 0.3935 - val_accuracy: 0.8298
# Epoch 46/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3921 - accuracy: 0.8315 - val_loss: 0.3930 - val_accuracy: 0.8299
# Epoch 47/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3916 - accuracy: 0.8319 - val_loss: 0.3925 - val_accuracy: 0.8302
# Epoch 48/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3911 - accuracy: 0.8321 - val_loss: 0.3921 - val_accuracy: 0.8302
# Epoch 49/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3906 - accuracy: 0.8324 - val_loss: 0.3915 - val_accuracy: 0.8309
# Epoch 50/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3901 - accuracy: 0.8324 - val_loss: 0.3911 - val_accuracy: 0.8311
# Epoch 51/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3897 - accuracy: 0.8327 - val_loss: 0.3907 - val_accuracy: 0.8310
# Epoch 52/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3893 - accuracy: 0.8326 - val_loss: 0.3903 - val_accuracy: 0.8314
# Epoch 53/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3889 - accuracy: 0.8329 - val_loss: 0.3898 - val_accuracy: 0.8315
# Epoch 54/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3885 - accuracy: 0.8331 - val_loss: 0.3895 - val_accuracy: 0.8317
# Epoch 55/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3881 - accuracy: 0.8332 - val_loss: 0.3891 - val_accuracy: 0.8318
# Epoch 56/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3877 - accuracy: 0.8333 - val_loss: 0.3888 - val_accuracy: 0.8320
# Epoch 57/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3874 - accuracy: 0.8334 - val_loss: 0.3884 - val_accuracy: 0.8325
# Epoch 58/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3870 - accuracy: 0.8339 - val_loss: 0.3881 - val_accuracy: 0.8327
# Epoch 59/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3867 - accuracy: 0.8337 - val_loss: 0.3878 - val_accuracy: 0.8324
# Epoch 60/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3864 - accuracy: 0.8339 - val_loss: 0.3875 - val_accuracy: 0.8328
# Epoch 61/100
# 728/728 [==============================] - 4s 5ms/step - loss: 0.3861 - accuracy: 0.8341 - val_loss: 0.3871 - val_accuracy: 0.8329
# Epoch 62/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3858 - accuracy: 0.8341 - val_loss: 0.3869 - val_accuracy: 0.8327
# Epoch 63/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3855 - accuracy: 0.8342 - val_loss: 0.3866 - val_accuracy: 0.8331
# Epoch 64/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3852 - accuracy: 0.8344 - val_loss: 0.3863 - val_accuracy: 0.8329
# Epoch 65/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3850 - accuracy: 0.8342 - val_loss: 0.3860 - val_accuracy: 0.8332
# Epoch 66/100
# 728/728 [==============================] - 5s 7ms/step - loss: 0.3847 - accuracy: 0.8345 - val_loss: 0.3858 - val_accuracy: 0.8335
# Epoch 67/100
# 728/728 [==============================] - 4s 6ms/step - loss: 0.3844 - accuracy: 0.8347 - val_loss: 0.3855 - val_accuracy: 0.8335
# Epoch 68/100
# 728/728 [==============================] - 4s 5ms/step - loss: 0.3842 - accuracy: 0.8350 - val_loss: 0.3853 - val_accuracy: 0.8333
# Epoch 69/100
# 728/728 [==============================] - 3s 4ms/step - loss: 0.3839 - accuracy: 0.8350 - val_loss: 0.3851 - val_accuracy: 0.8336
# Epoch 70/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3837 - accuracy: 0.8351 - val_loss: 0.3848 - val_accuracy: 0.8336
# Epoch 71/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3835 - accuracy: 0.8351 - val_loss: 0.3846 - val_accuracy: 0.8337
# Epoch 72/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3833 - accuracy: 0.8352 - val_loss: 0.3844 - val_accuracy: 0.8332
# Epoch 73/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3831 - accuracy: 0.8354 - val_loss: 0.3842 - val_accuracy: 0.8335
# Epoch 74/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3829 - accuracy: 0.8354 - val_loss: 0.3840 - val_accuracy: 0.8332
# Epoch 75/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3827 - accuracy: 0.8354 - val_loss: 0.3839 - val_accuracy: 0.8334
# Epoch 76/100
# 728/728 [==============================] - 2s 2ms/step - loss: 0.3825 - accuracy: 0.8355 - val_loss: 0.3836 - val_accuracy: 0.8336
# Epoch 77/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3823 - accuracy: 0.8356 - val_loss: 0.3835 - val_accuracy: 0.8342
# Epoch 78/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3821 - accuracy: 0.8359 - val_loss: 0.3834 - val_accuracy: 0.8338
# Epoch 79/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3819 - accuracy: 0.8360 - val_loss: 0.3832 - val_accuracy: 0.8338
# Epoch 80/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3817 - accuracy: 0.8361 - val_loss: 0.3830 - val_accuracy: 0.8340
# Epoch 81/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3816 - accuracy: 0.8361 - val_loss: 0.3828 - val_accuracy: 0.8345
# Epoch 82/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3814 - accuracy: 0.8363 - val_loss: 0.3827 - val_accuracy: 0.8350
# Epoch 83/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3813 - accuracy: 0.8362 - val_loss: 0.3825 - val_accuracy: 0.8341
# Epoch 84/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3811 - accuracy: 0.8363 - val_loss: 0.3823 - val_accuracy: 0.8350
# Epoch 85/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3809 - accuracy: 0.8363 - val_loss: 0.3822 - val_accuracy: 0.8355
# Epoch 86/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3808 - accuracy: 0.8365 - val_loss: 0.3821 - val_accuracy: 0.8347
# Epoch 87/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3806 - accuracy: 0.8366 - val_loss: 0.3820 - val_accuracy: 0.8353
# Epoch 88/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3805 - accuracy: 0.8367 - val_loss: 0.3818 - val_accuracy: 0.8355
# Epoch 89/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3803 - accuracy: 0.8366 - val_loss: 0.3817 - val_accuracy: 0.8357
# Epoch 90/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3802 - accuracy: 0.8370 - val_loss: 0.3816 - val_accuracy: 0.8353
# Epoch 91/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3800 - accuracy: 0.8368 - val_loss: 0.3814 - val_accuracy: 0.8358
# Epoch 92/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3799 - accuracy: 0.8369 - val_loss: 0.3813 - val_accuracy: 0.8359
# Epoch 93/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3798 - accuracy: 0.8370 - val_loss: 0.3812 - val_accuracy: 0.8360
# Epoch 94/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3796 - accuracy: 0.8370 - val_loss: 0.3811 - val_accuracy: 0.8361
# Epoch 95/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3795 - accuracy: 0.8371 - val_loss: 0.3809 - val_accuracy: 0.8360
# Epoch 96/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3794 - accuracy: 0.8369 - val_loss: 0.3808 - val_accuracy: 0.8364
# Epoch 97/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3792 - accuracy: 0.8373 - val_loss: 0.3806 - val_accuracy: 0.8365
# Epoch 98/100
# 728/728 [==============================] - 2s 2ms/step - loss: 0.3791 - accuracy: 0.8373 - val_loss: 0.3806 - val_accuracy: 0.8363
# Epoch 99/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3790 - accuracy: 0.8370 - val_loss: 0.3804 - val_accuracy: 0.8366
# Epoch 100/100
# 728/728 [==============================] - 2s 3ms/step - loss: 0.3789 - accuracy: 0.8374 - val_loss: 0.3803 - val_accuracy: 0.8368

# %%
history_df = pd.DataFrame(history.history)

plt.figure(figsize= (12,6))
plt.plot(history_df.loc[:, ['accuracy']], color="red", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], color="blue", label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Predicting the test set results

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90     22612
#            1       0.72      0.42      0.53      6480
#
#     accuracy                           0.83     29092
#    macro avg       0.78      0.69      0.72     29092
# weighted avg       0.82      0.83      0.82     29092

# %%
# Confusion Matrix
plot_cm(y_test, y_pred, figsize=(12,8))
